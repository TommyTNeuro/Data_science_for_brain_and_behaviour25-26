# %% [markdown]
# # Supplementary Guide : Git

# %% [markdown]
# This guide is for those interested in learning about some additional programming concepts and tools that are adjacent to but not necessary to know to pass the module. These guides will cover background information, their place in the programming world, practical advice on how you can use these practically in your programming career. This is a part of a set of guides - this guide is particularly on git.
#
# What is git?
