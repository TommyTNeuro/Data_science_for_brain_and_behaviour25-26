# %% [markdown]
# # Supplementary Guide to Data Science for Brain and Behaviour

# %% [markdown]
# This guide will distil key areas of the course content into a single notebook to save you from jumping from notebook to notebook. It will also provide some general advice, tips and tricks, and additional resources that may be useful.

# %% [markdown]
# ```This content will generally be in the order it's presented to you in the lectures, however as this course builds on content you have used in previous lectures it will be grouped by it's function rather than week.```

# %% [markdown]
# To naviate this notebook in your jupyter lab environment click the 3 lines icon on the left side of the screen that is called "Table of Contents". This will allow you to navigate the notebook to the section you are looking for.

# %% [markdown]
# ## General Advice

# %% [markdown]
# If you are struggling to solve a problem take a step away from the computer and solve it in natural lanuage before returning to python

# %% [markdown]
# ### Useful Keyboard Shortcuts

# %% [markdown]
# To use these short cuts make sure you are not in *Edit* mode, you can do this my pressing *esc* on you keyboard

# %% [markdown]
# - ```b```  [add cell below]
# - ```u```  [add cell above]
# - ```m```  [change cell to markdown]
# - ```y```  [change cell to code]

# %% [markdown]
# ## Basic Python
#
# This section will describe the basic functions of python

# %% [markdown]
# ### Useful Python Documentation and tutorials
#
# **Offical Python Documentation**
#  - https://docs.python.org/3/
#
# **Offical Jupyter Lab Documentation**
#  - https://docs.jupyter.org/en/latest/
#
# **Khan Academy Python Tutorial**
#  - https://www.khanacademy.org/computing/intro-to-python-fundamentals

# %% [markdown]
# ### Variables

# %%
# To Store a Variable use =
string_variable_name = "string variable"
integer_variable_name = 10
float_variable_name = 1.5

# %% [markdown]
# For naming variable python uses snake_case which just means that the variables are all lowercase with _ seperating the words. Python is case-sensitive so always check that your variables match in case as well.

# %% [markdown]
# ### Mathematical Operators

# %%
# The answer is stored in the variable
addition_answer = 1 + 2
subtraction_answer = 1 - 2
division_answer = 1 / 2
multiplication_answer = 1 * 2
squaring_answer = 1**2

# Variables are just labels for the value they store
adding_variables = addition + multiplication_answer
print(adding_variables)

# %% [markdown]
# ## Adding Strings

# %%
# You can even add strings
string_concat = "Hello " + "World"
print(string_concat)

# %% [markdown]
# ## Boolean Values

# %% [markdown]
# These are values that return a True or False value

# %%
# These statements are mathematical boolean operators

# Is 1 the same as 1?
true_value = 1 == 1

# Is 1 not the same as 2
true_value = 1 != 2

# Is 1 greater than 2
false_value = 1 > 2

# Is 1 less than 2
true_value = 1 < 2

# %%
# Logical boolean values

# Or

# And

# Not

# %% [markdown]
# ## Permutation Tests

# %% [markdown]
# ### Useful documentation and tutorials on permutation tests
#
# Simple Graphical Guide to Permuation tests
#  - https://www.jwilber.me/permutationtest
