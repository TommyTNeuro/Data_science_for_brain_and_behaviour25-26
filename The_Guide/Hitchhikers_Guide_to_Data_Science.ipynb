# %% [markdown]
# # Hitchhikers Guide to Data Science

# %% [markdown]
# > DON'T PANIC

# %% [markdown]
# ## How to use this Notebook
#
# This notebook is designed as a reference for your content from the module, you should not read it cover to cover. First read this section on how to use the notebook then naviate to sections that you wish to learn more about.

# %% [markdown]
# ### Navigation

# %% [markdown]
# Taking a look to the left of your screen you will see a bar with a folder icon. The third icon down with 3 horizontal lines shows you a "Table of contents" for the notebook, here you can see which sections are the most useful to you and skip to them.
#
# ![Navigation Bar](Navigation_Bar.png)

# %% [markdown]
# ### For the Journey Ahead

# %% [markdown]
# The this guide is built for teaches 2 subjects in parellel however the empathsis is on the first subject.
#
# **Subject 1:** Data Science
#
# This is the primary goal of this course to teach your the concepts of how to work with data and how to use data to empower your analysis. This is the most important subject to understand. To test you understanding of this subject, I suggest taking a step away from the screen and writing the steps that you would take with the data in plain english before returning to perform any coding - hinting at the second subject.
#
# **Subject 2:** Python
#
# The second subject is python, this is really the tool to perform the concepts that are taught in this course. You could do the same with a different coding language or by pen and paper. Using python is a way to automate things that would take far to long to do by hand, however it's important to note that early data scientists did perform these calculations by hand.
#
# The reason the first concept is the most important is because no one expects you to learn all the python syntax, this will come naturally over time. Understanding how and why you are performing actions on the data will mean you work in python is simply and act of translation.

# %% [markdown]
# ## Python Resources
#
# This section will point you to some useful python resources to help you along you python journey

# %% [markdown]
# ### Python Documentation
#
# **Offical Python Documentation**
#  - https://docs.python.org/3/
#
# **Offical Jupyter Lab Documentation**
#  - https://docs.jupyter.org/en/latest/

# %% [markdown]
# ### Python Tutorials
#
# **Khan Academy Python Tutorial**
#  - https://www.khanacademy.org/computing/intro-to-python-fundamentals

# %% [markdown]
# ## Permutation Tests

# %% [markdown]
# ### Useful Resources for Permutation Tests
#
# Simple Graphical Guide to Permuation tests
#  - https://www.jwilber.me/permutationtest

# %% [markdown]
# ## Advanced Concepts (User Beware)

# %% [markdown]
# ### Useful Keyboard Shortcuts
#
# To use these shortcuts make sure you are not in *Edit* mode, you can do this by pressing *esc* on your keyboard.
#
# - ```b```  [add cell below]
# - ```u```  [add cell above]
# - ```m```  [change cell to markdown]
# - ```y```  [change cell to code]

# %% [markdown]
# ### Git
#
# Git is a version control system for

# %% [markdown]
# ### Linux

# %% [markdown]
# ## Appendix
